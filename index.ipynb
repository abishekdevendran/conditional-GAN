# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import cv2
import math

# %%
class MascotDataset(Dataset):
	def __init__(self, spritesheet_path, num_characters, num_poses):
		"""
		Dataset class for mascot sprites with automatic dimension detection
		
		Args:
			spritesheet_path: Path to master spritesheet
			num_characters: Number of character rows in spritesheet
			num_poses: Number of pose columns in spritesheet
		"""
		self.spritesheet = cv2.imread(spritesheet_path)
		if self.spritesheet is None:
			raise ValueError(f"Could not load spritesheet from {
							 spritesheet_path}")

		self.num_characters = num_characters
		self.num_poses = num_poses

		# Calculate sprite dimensions from spritesheet
		sheet_height, sheet_width = self.spritesheet.shape[:2]
		self.sprite_height = sheet_height // num_characters
		self.sprite_width = sheet_width // num_poses

		if sheet_height % num_characters != 0 or sheet_width % num_poses != 0:
			raise ValueError(
				f"Spritesheet dimensions ({sheet_width}x{
					sheet_height}) are not "
				f"evenly divisible by grid size ({num_poses}x{num_characters})"
			)

		print(f"Detected sprite dimensions: {
			  self.sprite_width}x{self.sprite_height}")

		# Calculate padding to make dimensions divisible by 8 (for 3 downsample operations)
		self.pad_height = math.ceil(
			self.sprite_height / 8) * 8 - self.sprite_height
		self.pad_width = math.ceil(
			self.sprite_width / 8) * 8 - self.sprite_width

		self.padded_height = self.sprite_height + self.pad_height
		self.padded_width = self.sprite_width + self.pad_width

		if self.pad_height > 0 or self.pad_width > 0:
			print(f"Padding sprites to {self.padded_width}x{self.padded_height} "
				  f"(added {self.pad_width}x{self.pad_height} pixels)")

		# Extract and pad individual sprites
		self.sprites = []
		for i in range(self.num_characters):
			character_poses = []
			for j in range(self.num_poses):
				if j<5:
					continue
				# Extract sprite
				y_start = i * self.sprite_height
				x_start = j * self.sprite_width
				sprite = self.spritesheet[
					y_start:y_start + self.sprite_height,
					x_start:x_start + self.sprite_width
				]

				# Pad if necessary
				if self.pad_height > 0 or self.pad_width > 0:
					sprite = np.pad(
						sprite,
						((0, self.pad_height), (0, self.pad_width), (0, 0)),
						mode='constant',
						constant_values=0
					)
				character_poses.append(sprite)
			self.sprites.append(character_poses)

		self.sprites = np.array(self.sprites)

	def __len__(self):
		return self.num_characters * (self.num_poses -5 - 1)

	def __getitem__(self, idx):
		character_idx = idx // ((self.num_poses-5) - 1)
		pose_idx = (idx % ((self.num_poses-5) - 1)) + 1

		input_pose = self.sprites[character_idx, 0]
		target_pose = self.sprites[character_idx, pose_idx]

		input_pose = torch.FloatTensor(input_pose).permute(2, 0, 1) / 255.0
		target_pose = torch.FloatTensor(target_pose).permute(2, 0, 1) / 255.0

		return input_pose, target_pose

	def get_sprite_dimensions(self):
		"""Return the original (unpadded) sprite dimensions"""
		return self.sprite_width, self.sprite_height

# %%
class PoseGenerator(nn.Module):
    def __init__(self, input_height, input_width, base_channels=64, num_poses=25):
        """
        Generator network that automatically configures its architecture based on input dimensions
        
        Args:
            input_height: Height of input sprites (after padding)
            input_width: Width of input sprites (after padding)
            base_channels: Number of channels in first conv layer (doubles in subsequent layers)
            num_poses: Number of poses to generate (excluding input pose)
        """
        super(PoseGenerator, self).__init__()

        if not (input_height % 8 == 0 and input_width % 8 == 0):
            raise ValueError(
                "Input dimensions must be divisible by 8 for 3 downsample operations")

        # Calculate dimensions at each layer
        dims = self._calculate_dimensions(input_height, input_width)

        # Calculate channel progression (e.g., 3 -> 64 -> 128 -> 256)
        channels = [3] + [base_channels * (2**i) for i in range(3)]

        print(f"PoseGenerator Architecture:")
        print(f"Input size: {input_width}x{input_height}x{channels[0]}")

        # Build encoder layers dynamically
        encoder_layers = []
        for i in range(len(channels)-1):
            in_ch, out_ch = channels[i], channels[i+1]
            layer = [
                nn.Conv2d(in_ch, out_ch, kernel_size=4, stride=2, padding=1),
                nn.LeakyReLU(0.2) if i == 0 else nn.BatchNorm2d(out_ch),
                nn.LeakyReLU(0.2)
            ]
            encoder_layers.extend(layer)
            print(f"Encoder layer {
                  i+1}: {dims[i+1][1]}x{dims[i+1][0]}x{out_ch}")

        self.encoder = nn.Sequential(*encoder_layers)

        # Pose embedding matches the final encoder channel count
        self.pose_embedding = nn.Parameter(
            torch.randn(num_poses, channels[-1]))
        print(f"Pose embedding size: {num_poses}x{channels[-1]}")

        # Build decoder layers dynamically (reverse channel progression)
        decoder_layers = []
        channels = channels[::-1]  # Reverse channel list for decoder
        for i in range(len(channels)-1):
            # Double first input for concatenation
            in_ch = channels[i] * 2 if i == 0 else channels[i]
            out_ch = channels[i+1]
            layer = [
                nn.ConvTranspose2d(
                    in_ch, out_ch, kernel_size=4, stride=2, padding=1),
                nn.BatchNorm2d(out_ch) if i < len(
                    channels)-2 else nn.Identity(),
                nn.ReLU() if i < len(channels)-2 else nn.Tanh()
            ]
            decoder_layers.extend(layer)
            print(f"Decoder layer {
                  i+1}: {dims[-(i+2)][1]}x{dims[-(i+2)][0]}x{out_ch}")

        self.decoder = nn.Sequential(*decoder_layers)

        # Save dimensions for forward pass
        self.bottleneck_shape = dims[3]  # Shape after encoder

    def _calculate_dimensions(self, height, width):
        """Calculate dimensions at each layer of the network"""
        dims = [(height, width)]  # Input dimensions

        # Calculate encoder dimensions (3 downsampling layers)
        for _ in range(3):
            height = height // 2
            width = width // 2
            dims.append((height, width))

        # Calculate decoder dimensions (3 upsampling layers)
        for _ in range(3):
            height = height * 2
            width = width * 2
            dims.append((height, width))

        return dims

    def forward(self, x, pose_idx):
        """
        Forward pass through the generator
        
        Args:
            x: Input pose tensor (B, 3, H, W)
            pose_idx: Indices of target poses to generate (B,)
        """
        # Encode input
        encoded = self.encoder(x)
        batch_size = x.size(0)

        # Get pose embeddings for requested indices
        pose_embed = self.pose_embedding[pose_idx]

        # Reshape pose embedding to match encoded dimensions
        pose_embed = pose_embed.view(batch_size, -1, 1, 1)
        pose_embed = pose_embed.expand(-1, -1,
                                       self.bottleneck_shape[0], self.bottleneck_shape[1])

        # Combine encoded image and pose embedding
        combined = torch.cat([encoded, pose_embed], dim=1)

        # Generate output pose
        output = self.decoder(combined)
        return output

# %%
def create_model_for_dataset(dataset):
    """
    Create a PoseGenerator model with appropriate dimensions for the dataset
    """
    return PoseGenerator(
        input_height=dataset.padded_height,
        input_width=dataset.padded_width
    )

# %%
def train_model(model, dataset, num_epochs=1000, batch_size=32*6, learning_rate=0.00002):
    """
    Training function for the pose generator
    """
    # Check if GPU is available and set device accordingly
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    for epoch in range(num_epochs):
        for i, (input_poses, target_poses) in enumerate(dataloader):
            if torch.cuda.is_available():
                input_poses = input_poses.to(device)
                target_poses = target_poses.to(device)
            # Generate random pose indices
            pose_indices = torch.randint(0, 19, (input_poses.size(0),))

            # Generate new poses
            generated_poses = model(input_poses, pose_indices)

            # Calculate loss
            loss = criterion(generated_poses, target_poses)

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if i % 100 == 0:
                print(f'Epoch [{
                      epoch}/{num_epochs}], Step [{i}/{len(dataloader)}], Loss: {loss.item():.4f}')

# %%
def generate_spritesheet(model, input_pose, num_poses, original_width, original_height):
	"""
	Generate a complete spritesheet for a new mascot
	
	Args:
		model: Trained PoseGenerator model
		input_pose: First pose of the new character
		num_poses: Number of poses to generate
		original_width: Width of the original (unpadded) sprites
		original_height: Height of the original (unpadded) sprites
	"""
	model.eval()

	# Create empty spritesheet
	spritesheet = np.zeros(
		(original_height, original_width * num_poses, 3),
		dtype=np.uint8
	)

	# Calculate padding needed to match model's expected input
	pad_height = math.ceil(original_height / 8) * 8 - original_height
	pad_width = math.ceil(original_width / 8) * 8 - original_width

	# Pad input pose if necessary
	if pad_height > 0 or pad_width > 0:
		padded_input = np.pad(
			input_pose,
			((0, pad_height), (0, pad_width), (0, 0)),
			mode='constant',
			constant_values=0
		)
	else:
		padded_input = input_pose

	# Place the input pose first
	spritesheet[:, :original_width] = input_pose

	# Generate all other poses
	with torch.no_grad():
		input_tensor = torch.FloatTensor(padded_input).permute(2, 0, 1) / 255.0
		input_tensor = input_tensor.unsqueeze(0).to(next(model.parameters()).device)

		for i in range(num_poses - 1):
			# Generate padded pose
			generated_pose = model(input_tensor, torch.tensor([i]).to(input_tensor.device))
			generated_pose = generated_pose.squeeze(0).permute(1, 2, 0)
			generated_pose = (generated_pose.cpu().numpy() * 255).astype(np.uint8)

			# Remove padding
			generated_pose = generated_pose[:original_height, :original_width]

			# Place in spritesheet
			x_offset = (i + 1) * original_width
			spritesheet[:, x_offset:x_offset+original_width] = generated_pose

	return spritesheet

# %%
# Example usage:
if True:
    # Load dataset
    dataset = MascotDataset('main.png',
                            num_characters=24, num_poses=26)
    
	# save first sprite to local to preview
    cv2.imwrite('first.png', dataset.sprites[0, 0])

    # Create and initialize model
    model = create_model_for_dataset(dataset)
    # print("Dataset: ", dataset[0])
    
	# Train model
    train_model(model, dataset)
# Out:
# Detected sprite dimensions: 45x50
# Padding sprites to 48x56 (added 3x6 pixels)
# PoseGenerator Architecture:
# Input size: 48x56x3
# Encoder layer 1: 24x28x64
# Encoder layer 2: 12x14x128
# Encoder layer 3: 6x7x256
# Pose embedding size: 25x256
# Decoder layer 1: 24x28x128
# Decoder layer 2: 12x14x64
# Decoder layer 3: 6x7x3
# Epoch [0/1000], Step [0/3], Loss: 0.3655
# Epoch [1/1000], Step [0/3], Loss: 0.3398
# Epoch [2/1000], Step [0/3], Loss: 0.3199
# Epoch [3/1000], Step [0/3], Loss: 0.2990
# Epoch [4/1000], Step [0/3], Loss: 0.2794
# Epoch [5/1000], Step [0/3], Loss: 0.2601
# Epoch [6/1000], Step [0/3], Loss: 0.2449
# Epoch [7/1000], Step [0/3], Loss: 0.2320
# Epoch [8/1000], Step [0/3], Loss: 0.2163
# Epoch [9/1000], Step [0/3], Loss: 0.2025
# Epoch [10/1000], Step [0/3], Loss: 0.1895
# Epoch [11/1000], Step [0/3], Loss: 0.1789
# Epoch [12/1000], Step [0/3], Loss: 0.1654
# Epoch [13/1000], Step [0/3], Loss: 0.1560
# Epoch [14/1000], Step [0/3], Loss: 0.1445
# Epoch [15/1000], Step [0/3], Loss: 0.1349
# Epoch [16/1000], Step [0/3], Loss: 0.1273
# Epoch [17/1000], Step [0/3], Loss: 0.1204
# Epoch [18/1000], Step [0/3], Loss: 0.1121
# Epoch [19/1000], Step [0/3], Loss: 0.1075
# Epoch [20/1000], Step [0/3], Loss: 0.1005
# Epoch [21/1000], Step [0/3], Loss: 0.0966
# Epoch [22/1000], Step [0/3], Loss: 0.0896
# Epoch [23/1000], Step [0/3], Loss: 0.0868
# Epoch [24/1000], Step [0/3], Loss: 0.0818
# Epoch [25/1000], Step [0/3], Loss: 0.0797
# Epoch [26/1000], Step [0/3], Loss: 0.0771
# Epoch [27/1000], Step [0/3], Loss: 0.0751
# Epoch [28/1000], Step [0/3], Loss: 0.0735
# Epoch [29/1000], Step [0/3], Loss: 0.0698
# Epoch [30/1000], Step [0/3], Loss: 0.0692
# Epoch [31/1000], Step [0/3], Loss: 0.0664
# Epoch [32/1000], Step [0/3], Loss: 0.0627
# Epoch [33/1000], Step [0/3], Loss: 0.0613
# Epoch [34/1000], Step [0/3], Loss: 0.0626
# Epoch [35/1000], Step [0/3], Loss: 0.0606
# Epoch [36/1000], Step [0/3], Loss: 0.0579
# Epoch [37/1000], Step [0/3], Loss: 0.0568
# Epoch [38/1000], Step [0/3], Loss: 0.0558
# Epoch [39/1000], Step [0/3], Loss: 0.0554
# Epoch [40/1000], Step [0/3], Loss: 0.0559
# Epoch [41/1000], Step [0/3], Loss: 0.0530
# Epoch [42/1000], Step [0/3], Loss: 0.0537
# Epoch [43/1000], Step [0/3], Loss: 0.0499
# Epoch [44/1000], Step [0/3], Loss: 0.0512
# Epoch [45/1000], Step [0/3], Loss: 0.0495
# Epoch [46/1000], Step [0/3], Loss: 0.0486
# Epoch [47/1000], Step [0/3], Loss: 0.0483
# Epoch [48/1000], Step [0/3], Loss: 0.0475
# Epoch [49/1000], Step [0/3], Loss: 0.0482
# Epoch [50/1000], Step [0/3], Loss: 0.0447
# Epoch [51/1000], Step [0/3], Loss: 0.0451
# Epoch [52/1000], Step [0/3], Loss: 0.0446
# Epoch [53/1000], Step [0/3], Loss: 0.0450
# Epoch [54/1000], Step [0/3], Loss: 0.0433
# Epoch [55/1000], Step [0/3], Loss: 0.0434
# Epoch [56/1000], Step [0/3], Loss: 0.0432
# Epoch [57/1000], Step [0/3], Loss: 0.0418
# Epoch [58/1000], Step [0/3], Loss: 0.0399
# Epoch [59/1000], Step [0/3], Loss: 0.0407
# Epoch [60/1000], Step [0/3], Loss: 0.0405
# Epoch [61/1000], Step [0/3], Loss: 0.0400
# Epoch [62/1000], Step [0/3], Loss: 0.0397
# Epoch [63/1000], Step [0/3], Loss: 0.0369
# Epoch [64/1000], Step [0/3], Loss: 0.0387
# Epoch [65/1000], Step [0/3], Loss: 0.0386
# Epoch [66/1000], Step [0/3], Loss: 0.0361
# Epoch [67/1000], Step [0/3], Loss: 0.0379
# Epoch [68/1000], Step [0/3], Loss: 0.0361
# Epoch [69/1000], Step [0/3], Loss: 0.0356
# Epoch [70/1000], Step [0/3], Loss: 0.0359
# Epoch [71/1000], Step [0/3], Loss: 0.0354
# Epoch [72/1000], Step [0/3], Loss: 0.0342
# Epoch [73/1000], Step [0/3], Loss: 0.0360
# Epoch [74/1000], Step [0/3], Loss: 0.0347
# Epoch [75/1000], Step [0/3], Loss: 0.0336
# Epoch [76/1000], Step [0/3], Loss: 0.0339
# Epoch [77/1000], Step [0/3], Loss: 0.0344
# Epoch [78/1000], Step [0/3], Loss: 0.0351
# Epoch [79/1000], Step [0/3], Loss: 0.0326
# Epoch [80/1000], Step [0/3], Loss: 0.0350
# Epoch [81/1000], Step [0/3], Loss: 0.0323
# Epoch [82/1000], Step [0/3], Loss: 0.0336
# Epoch [83/1000], Step [0/3], Loss: 0.0318
# Epoch [84/1000], Step [0/3], Loss: 0.0326
# Epoch [85/1000], Step [0/3], Loss: 0.0315
# Epoch [86/1000], Step [0/3], Loss: 0.0318
# Epoch [87/1000], Step [0/3], Loss: 0.0310
# Epoch [88/1000], Step [0/3], Loss: 0.0323
# Epoch [89/1000], Step [0/3], Loss: 0.0322
# Epoch [90/1000], Step [0/3], Loss: 0.0321
# Epoch [91/1000], Step [0/3], Loss: 0.0305
# Epoch [92/1000], Step [0/3], Loss: 0.0303
# Epoch [93/1000], Step [0/3], Loss: 0.0314
# Epoch [94/1000], Step [0/3], Loss: 0.0302
# Epoch [95/1000], Step [0/3], Loss: 0.0298
# Epoch [96/1000], Step [0/3], Loss: 0.0308
# Epoch [97/1000], Step [0/3], Loss: 0.0309
# Epoch [98/1000], Step [0/3], Loss: 0.0302
# Epoch [99/1000], Step [0/3], Loss: 0.0291
# Epoch [100/1000], Step [0/3], Loss: 0.0293
# Epoch [101/1000], Step [0/3], Loss: 0.0307
# Epoch [102/1000], Step [0/3], Loss: 0.0300
# Epoch [103/1000], Step [0/3], Loss: 0.0300
# Epoch [104/1000], Step [0/3], Loss: 0.0305
# Epoch [105/1000], Step [0/3], Loss: 0.0287
# Epoch [106/1000], Step [0/3], Loss: 0.0286
# Epoch [107/1000], Step [0/3], Loss: 0.0285
# Epoch [108/1000], Step [0/3], Loss: 0.0292
# Epoch [109/1000], Step [0/3], Loss: 0.0279
# Epoch [110/1000], Step [0/3], Loss: 0.0288
# Epoch [111/1000], Step [0/3], Loss: 0.0284
# Epoch [112/1000], Step [0/3], Loss: 0.0297
# Epoch [113/1000], Step [0/3], Loss: 0.0280
# Epoch [114/1000], Step [0/3], Loss: 0.0286
# Epoch [115/1000], Step [0/3], Loss: 0.0287
# Epoch [116/1000], Step [0/3], Loss: 0.0282
# Epoch [117/1000], Step [0/3], Loss: 0.0275
# Epoch [118/1000], Step [0/3], Loss: 0.0282
# Epoch [119/1000], Step [0/3], Loss: 0.0279
# Epoch [120/1000], Step [0/3], Loss: 0.0282
# Epoch [121/1000], Step [0/3], Loss: 0.0273
# Epoch [122/1000], Step [0/3], Loss: 0.0267
# Epoch [123/1000], Step [0/3], Loss: 0.0272
# Epoch [124/1000], Step [0/3], Loss: 0.0271
# Epoch [125/1000], Step [0/3], Loss: 0.0272
# Epoch [126/1000], Step [0/3], Loss: 0.0268
# Epoch [127/1000], Step [0/3], Loss: 0.0274
# Epoch [128/1000], Step [0/3], Loss: 0.0275
# Epoch [129/1000], Step [0/3], Loss: 0.0271
# Epoch [130/1000], Step [0/3], Loss: 0.0263
# Epoch [131/1000], Step [0/3], Loss: 0.0267
# Epoch [132/1000], Step [0/3], Loss: 0.0285
# Epoch [133/1000], Step [0/3], Loss: 0.0281
# Epoch [134/1000], Step [0/3], Loss: 0.0268
# Epoch [135/1000], Step [0/3], Loss: 0.0266
# Epoch [136/1000], Step [0/3], Loss: 0.0266
# Epoch [137/1000], Step [0/3], Loss: 0.0262
# Epoch [138/1000], Step [0/3], Loss: 0.0265
# Epoch [139/1000], Step [0/3], Loss: 0.0272
# Epoch [140/1000], Step [0/3], Loss: 0.0267
# Epoch [141/1000], Step [0/3], Loss: 0.0292
# Epoch [142/1000], Step [0/3], Loss: 0.0263
# Epoch [143/1000], Step [0/3], Loss: 0.0267
# Epoch [144/1000], Step [0/3], Loss: 0.0262
# Epoch [145/1000], Step [0/3], Loss: 0.0257
# Epoch [146/1000], Step [0/3], Loss: 0.0267
# Epoch [147/1000], Step [0/3], Loss: 0.0254
# Epoch [148/1000], Step [0/3], Loss: 0.0272
# Epoch [149/1000], Step [0/3], Loss: 0.0252
# Epoch [150/1000], Step [0/3], Loss: 0.0261
# Epoch [151/1000], Step [0/3], Loss: 0.0261
# Epoch [152/1000], Step [0/3], Loss: 0.0258
# Epoch [153/1000], Step [0/3], Loss: 0.0250
# Epoch [154/1000], Step [0/3], Loss: 0.0249
# Epoch [155/1000], Step [0/3], Loss: 0.0238
# Epoch [156/1000], Step [0/3], Loss: 0.0242
# Epoch [157/1000], Step [0/3], Loss: 0.0257
# Epoch [158/1000], Step [0/3], Loss: 0.0251
# Epoch [159/1000], Step [0/3], Loss: 0.0261
# Epoch [160/1000], Step [0/3], Loss: 0.0250
# Epoch [161/1000], Step [0/3], Loss: 0.0247
# Epoch [162/1000], Step [0/3], Loss: 0.0248
# Epoch [163/1000], Step [0/3], Loss: 0.0249
# Epoch [164/1000], Step [0/3], Loss: 0.0246
# Epoch [165/1000], Step [0/3], Loss: 0.0242
# Epoch [166/1000], Step [0/3], Loss: 0.0237
# Epoch [167/1000], Step [0/3], Loss: 0.0240
# Epoch [168/1000], Step [0/3], Loss: 0.0240
# Epoch [169/1000], Step [0/3], Loss: 0.0235
# Epoch [170/1000], Step [0/3], Loss: 0.0232
# Epoch [171/1000], Step [0/3], Loss: 0.0238
# Epoch [172/1000], Step [0/3], Loss: 0.0246
# Epoch [173/1000], Step [0/3], Loss: 0.0232
# Epoch [174/1000], Step [0/3], Loss: 0.0250
# Epoch [175/1000], Step [0/3], Loss: 0.0239
# Epoch [176/1000], Step [0/3], Loss: 0.0232
# Epoch [177/1000], Step [0/3], Loss: 0.0227
# Epoch [178/1000], Step [0/3], Loss: 0.0249
# Epoch [179/1000], Step [0/3], Loss: 0.0245
# Epoch [180/1000], Step [0/3], Loss: 0.0240
# Epoch [181/1000], Step [0/3], Loss: 0.0226
# Epoch [182/1000], Step [0/3], Loss: 0.0250
# Epoch [183/1000], Step [0/3], Loss: 0.0250
# Epoch [184/1000], Step [0/3], Loss: 0.0234
# Epoch [185/1000], Step [0/3], Loss: 0.0246
# Epoch [186/1000], Step [0/3], Loss: 0.0243
# Epoch [187/1000], Step [0/3], Loss: 0.0236
# Epoch [188/1000], Step [0/3], Loss: 0.0230
# Epoch [189/1000], Step [0/3], Loss: 0.0243
# Epoch [190/1000], Step [0/3], Loss: 0.0239
# Epoch [191/1000], Step [0/3], Loss: 0.0233
# Epoch [192/1000], Step [0/3], Loss: 0.0245
# Epoch [193/1000], Step [0/3], Loss: 0.0242
# Epoch [194/1000], Step [0/3], Loss: 0.0235
# Epoch [195/1000], Step [0/3], Loss: 0.0225
# Epoch [196/1000], Step [0/3], Loss: 0.0235
# Epoch [197/1000], Step [0/3], Loss: 0.0236
# Epoch [198/1000], Step [0/3], Loss: 0.0231
# Epoch [199/1000], Step [0/3], Loss: 0.0239
# Epoch [200/1000], Step [0/3], Loss: 0.0238
# Epoch [201/1000], Step [0/3], Loss: 0.0222
# Epoch [202/1000], Step [0/3], Loss: 0.0228
# Epoch [203/1000], Step [0/3], Loss: 0.0232
# Epoch [204/1000], Step [0/3], Loss: 0.0228
# Epoch [205/1000], Step [0/3], Loss: 0.0227
# Epoch [206/1000], Step [0/3], Loss: 0.0238
# Epoch [207/1000], Step [0/3], Loss: 0.0246
# Epoch [208/1000], Step [0/3], Loss: 0.0224
# Epoch [209/1000], Step [0/3], Loss: 0.0236
# Epoch [210/1000], Step [0/3], Loss: 0.0241
# Epoch [211/1000], Step [0/3], Loss: 0.0235
# Epoch [212/1000], Step [0/3], Loss: 0.0229
# Epoch [213/1000], Step [0/3], Loss: 0.0244
# Epoch [214/1000], Step [0/3], Loss: 0.0234
# Epoch [215/1000], Step [0/3], Loss: 0.0241
# Epoch [216/1000], Step [0/3], Loss: 0.0244
# Epoch [217/1000], Step [0/3], Loss: 0.0226
# Epoch [218/1000], Step [0/3], Loss: 0.0227
# Epoch [219/1000], Step [0/3], Loss: 0.0232
# Epoch [220/1000], Step [0/3], Loss: 0.0227
# Epoch [221/1000], Step [0/3], Loss: 0.0231
# Epoch [222/1000], Step [0/3], Loss: 0.0221
# Epoch [223/1000], Step [0/3], Loss: 0.0221
# Epoch [224/1000], Step [0/3], Loss: 0.0231
# Epoch [225/1000], Step [0/3], Loss: 0.0226
# Epoch [226/1000], Step [0/3], Loss: 0.0230
# Epoch [227/1000], Step [0/3], Loss: 0.0220
# Epoch [228/1000], Step [0/3], Loss: 0.0231
# Epoch [229/1000], Step [0/3], Loss: 0.0235
# Epoch [230/1000], Step [0/3], Loss: 0.0227
# Epoch [231/1000], Step [0/3], Loss: 0.0237
# Epoch [232/1000], Step [0/3], Loss: 0.0232
# Epoch [233/1000], Step [0/3], Loss: 0.0221
# Epoch [234/1000], Step [0/3], Loss: 0.0230
# Epoch [235/1000], Step [0/3], Loss: 0.0229
# Epoch [236/1000], Step [0/3], Loss: 0.0217
# Epoch [237/1000], Step [0/3], Loss: 0.0229
# Epoch [238/1000], Step [0/3], Loss: 0.0231
# Epoch [239/1000], Step [0/3], Loss: 0.0225
# Epoch [240/1000], Step [0/3], Loss: 0.0231
# Epoch [241/1000], Step [0/3], Loss: 0.0231
# Epoch [242/1000], Step [0/3], Loss: 0.0231
# Epoch [243/1000], Step [0/3], Loss: 0.0228
# Epoch [244/1000], Step [0/3], Loss: 0.0228
# Epoch [245/1000], Step [0/3], Loss: 0.0232
# Epoch [246/1000], Step [0/3], Loss: 0.0233
# Epoch [247/1000], Step [0/3], Loss: 0.0224
# Epoch [248/1000], Step [0/3], Loss: 0.0239
# Epoch [249/1000], Step [0/3], Loss: 0.0238
# Epoch [250/1000], Step [0/3], Loss: 0.0225
# Epoch [251/1000], Step [0/3], Loss: 0.0237
# Epoch [252/1000], Step [0/3], Loss: 0.0218
# Epoch [253/1000], Step [0/3], Loss: 0.0222
# Epoch [254/1000], Step [0/3], Loss: 0.0224
# Epoch [255/1000], Step [0/3], Loss: 0.0231
# Epoch [256/1000], Step [0/3], Loss: 0.0225
# Epoch [257/1000], Step [0/3], Loss: 0.0232
# Epoch [258/1000], Step [0/3], Loss: 0.0221
# Epoch [259/1000], Step [0/3], Loss: 0.0213
# Epoch [260/1000], Step [0/3], Loss: 0.0216
# Epoch [261/1000], Step [0/3], Loss: 0.0224
# Epoch [262/1000], Step [0/3], Loss: 0.0228
# Epoch [263/1000], Step [0/3], Loss: 0.0225
# Epoch [264/1000], Step [0/3], Loss: 0.0221
# Epoch [265/1000], Step [0/3], Loss: 0.0221
# Epoch [266/1000], Step [0/3], Loss: 0.0240
# Epoch [267/1000], Step [0/3], Loss: 0.0213
# Epoch [268/1000], Step [0/3], Loss: 0.0223
# Epoch [269/1000], Step [0/3], Loss: 0.0233
# Epoch [270/1000], Step [0/3], Loss: 0.0220
# Epoch [271/1000], Step [0/3], Loss: 0.0221
# Epoch [272/1000], Step [0/3], Loss: 0.0211
# Epoch [273/1000], Step [0/3], Loss: 0.0220
# Epoch [274/1000], Step [0/3], Loss: 0.0222
# Epoch [275/1000], Step [0/3], Loss: 0.0237
# Epoch [276/1000], Step [0/3], Loss: 0.0223
# Epoch [277/1000], Step [0/3], Loss: 0.0214
# Epoch [278/1000], Step [0/3], Loss: 0.0207
# Epoch [279/1000], Step [0/3], Loss: 0.0222
# Epoch [280/1000], Step [0/3], Loss: 0.0224
# Epoch [281/1000], Step [0/3], Loss: 0.0214
# Epoch [282/1000], Step [0/3], Loss: 0.0218
# Epoch [283/1000], Step [0/3], Loss: 0.0237
# Epoch [284/1000], Step [0/3], Loss: 0.0220
# Epoch [285/1000], Step [0/3], Loss: 0.0219
# Epoch [286/1000], Step [0/3], Loss: 0.0233
# Epoch [287/1000], Step [0/3], Loss: 0.0224
# Epoch [288/1000], Step [0/3], Loss: 0.0220
# Epoch [289/1000], Step [0/3], Loss: 0.0227
# Epoch [290/1000], Step [0/3], Loss: 0.0216
# Epoch [291/1000], Step [0/3], Loss: 0.0212
# Epoch [292/1000], Step [0/3], Loss: 0.0220
# Epoch [293/1000], Step [0/3], Loss: 0.0223
# Epoch [294/1000], Step [0/3], Loss: 0.0219
# Epoch [295/1000], Step [0/3], Loss: 0.0215
# Epoch [296/1000], Step [0/3], Loss: 0.0229
# Epoch [297/1000], Step [0/3], Loss: 0.0218
# Epoch [298/1000], Step [0/3], Loss: 0.0231
# Epoch [299/1000], Step [0/3], Loss: 0.0221
# Epoch [300/1000], Step [0/3], Loss: 0.0216
# Epoch [301/1000], Step [0/3], Loss: 0.0223
# Epoch [302/1000], Step [0/3], Loss: 0.0223
# Epoch [303/1000], Step [0/3], Loss: 0.0214
# Epoch [304/1000], Step [0/3], Loss: 0.0217
# Epoch [305/1000], Step [0/3], Loss: 0.0213
# Epoch [306/1000], Step [0/3], Loss: 0.0224
# Epoch [307/1000], Step [0/3], Loss: 0.0208
# Epoch [308/1000], Step [0/3], Loss: 0.0226
# Epoch [309/1000], Step [0/3], Loss: 0.0206
# Epoch [310/1000], Step [0/3], Loss: 0.0221
# Epoch [311/1000], Step [0/3], Loss: 0.0224
# Epoch [312/1000], Step [0/3], Loss: 0.0212
# Epoch [313/1000], Step [0/3], Loss: 0.0220
# Epoch [314/1000], Step [0/3], Loss: 0.0211
# Epoch [315/1000], Step [0/3], Loss: 0.0212
# Epoch [316/1000], Step [0/3], Loss: 0.0221
# Epoch [317/1000], Step [0/3], Loss: 0.0214
# Epoch [318/1000], Step [0/3], Loss: 0.0226
# Epoch [319/1000], Step [0/3], Loss: 0.0230
# Epoch [320/1000], Step [0/3], Loss: 0.0207
# Epoch [321/1000], Step [0/3], Loss: 0.0217
# Epoch [322/1000], Step [0/3], Loss: 0.0226
# Epoch [323/1000], Step [0/3], Loss: 0.0217
# Epoch [324/1000], Step [0/3], Loss: 0.0212
# Epoch [325/1000], Step [0/3], Loss: 0.0212
# Epoch [326/1000], Step [0/3], Loss: 0.0219
# Epoch [327/1000], Step [0/3], Loss: 0.0231
# Epoch [328/1000], Step [0/3], Loss: 0.0219
# Epoch [329/1000], Step [0/3], Loss: 0.0206
# Epoch [330/1000], Step [0/3], Loss: 0.0206
# Epoch [331/1000], Step [0/3], Loss: 0.0219
# Epoch [332/1000], Step [0/3], Loss: 0.0220
# Epoch [333/1000], Step [0/3], Loss: 0.0211
# Epoch [334/1000], Step [0/3], Loss: 0.0220
# Epoch [335/1000], Step [0/3], Loss: 0.0203
# Epoch [336/1000], Step [0/3], Loss: 0.0209
# Epoch [337/1000], Step [0/3], Loss: 0.0206
# Epoch [338/1000], Step [0/3], Loss: 0.0218
# Epoch [339/1000], Step [0/3], Loss: 0.0211
# Epoch [340/1000], Step [0/3], Loss: 0.0210
# Epoch [341/1000], Step [0/3], Loss: 0.0211
# Epoch [342/1000], Step [0/3], Loss: 0.0206
# Epoch [343/1000], Step [0/3], Loss: 0.0214
# Epoch [344/1000], Step [0/3], Loss: 0.0221
# Epoch [345/1000], Step [0/3], Loss: 0.0217
# Epoch [346/1000], Step [0/3], Loss: 0.0221
# Epoch [347/1000], Step [0/3], Loss: 0.0211
# Epoch [348/1000], Step [0/3], Loss: 0.0210
# Epoch [349/1000], Step [0/3], Loss: 0.0211
# Epoch [350/1000], Step [0/3], Loss: 0.0211
# Epoch [351/1000], Step [0/3], Loss: 0.0223
# Epoch [352/1000], Step [0/3], Loss: 0.0212
# Epoch [353/1000], Step [0/3], Loss: 0.0217
# Epoch [354/1000], Step [0/3], Loss: 0.0207
# Epoch [355/1000], Step [0/3], Loss: 0.0209
# Epoch [356/1000], Step [0/3], Loss: 0.0216
# Epoch [357/1000], Step [0/3], Loss: 0.0207
# Epoch [358/1000], Step [0/3], Loss: 0.0212
# Epoch [359/1000], Step [0/3], Loss: 0.0211
# Epoch [360/1000], Step [0/3], Loss: 0.0219
# Epoch [361/1000], Step [0/3], Loss: 0.0205
# Epoch [362/1000], Step [0/3], Loss: 0.0224
# Epoch [363/1000], Step [0/3], Loss: 0.0219
# Epoch [364/1000], Step [0/3], Loss: 0.0215
# Epoch [365/1000], Step [0/3], Loss: 0.0210
# Epoch [366/1000], Step [0/3], Loss: 0.0216
# Epoch [367/1000], Step [0/3], Loss: 0.0219
# Epoch [368/1000], Step [0/3], Loss: 0.0208
# Epoch [369/1000], Step [0/3], Loss: 0.0207
# Epoch [370/1000], Step [0/3], Loss: 0.0228
# Epoch [371/1000], Step [0/3], Loss: 0.0220
# Epoch [372/1000], Step [0/3], Loss: 0.0213
# Epoch [373/1000], Step [0/3], Loss: 0.0212
# Epoch [374/1000], Step [0/3], Loss: 0.0208
# Epoch [375/1000], Step [0/3], Loss: 0.0213
# Epoch [376/1000], Step [0/3], Loss: 0.0216
# Epoch [377/1000], Step [0/3], Loss: 0.0210
# Epoch [378/1000], Step [0/3], Loss: 0.0217
# Epoch [379/1000], Step [0/3], Loss: 0.0218
# Epoch [380/1000], Step [0/3], Loss: 0.0210
# Epoch [381/1000], Step [0/3], Loss: 0.0206
# Epoch [382/1000], Step [0/3], Loss: 0.0224
# Epoch [383/1000], Step [0/3], Loss: 0.0213
# Epoch [384/1000], Step [0/3], Loss: 0.0215
# Epoch [385/1000], Step [0/3], Loss: 0.0215
# Epoch [386/1000], Step [0/3], Loss: 0.0227
# Epoch [387/1000], Step [0/3], Loss: 0.0211
# Epoch [388/1000], Step [0/3], Loss: 0.0220
# Epoch [389/1000], Step [0/3], Loss: 0.0211
# Epoch [390/1000], Step [0/3], Loss: 0.0202
# Epoch [391/1000], Step [0/3], Loss: 0.0207
# Epoch [392/1000], Step [0/3], Loss: 0.0224
# Epoch [393/1000], Step [0/3], Loss: 0.0215
# Epoch [394/1000], Step [0/3], Loss: 0.0211
# Epoch [395/1000], Step [0/3], Loss: 0.0216
# Epoch [396/1000], Step [0/3], Loss: 0.0211
# Epoch [397/1000], Step [0/3], Loss: 0.0220
# Epoch [398/1000], Step [0/3], Loss: 0.0212
# Epoch [399/1000], Step [0/3], Loss: 0.0206
# Epoch [400/1000], Step [0/3], Loss: 0.0210
# Epoch [401/1000], Step [0/3], Loss: 0.0216
# Epoch [402/1000], Step [0/3], Loss: 0.0220
# Epoch [403/1000], Step [0/3], Loss: 0.0198
# Epoch [404/1000], Step [0/3], Loss: 0.0212
# Epoch [405/1000], Step [0/3], Loss: 0.0202
# Epoch [406/1000], Step [0/3], Loss: 0.0201
# Epoch [407/1000], Step [0/3], Loss: 0.0210
# Epoch [408/1000], Step [0/3], Loss: 0.0223
# Epoch [409/1000], Step [0/3], Loss: 0.0206
# Epoch [410/1000], Step [0/3], Loss: 0.0207
# Epoch [411/1000], Step [0/3], Loss: 0.0210
# Epoch [412/1000], Step [0/3], Loss: 0.0201
# Epoch [413/1000], Step [0/3], Loss: 0.0206
# Epoch [414/1000], Step [0/3], Loss: 0.0212
# Epoch [415/1000], Step [0/3], Loss: 0.0213
# Epoch [416/1000], Step [0/3], Loss: 0.0213
# Epoch [417/1000], Step [0/3], Loss: 0.0215
# Epoch [418/1000], Step [0/3], Loss: 0.0195
# Epoch [419/1000], Step [0/3], Loss: 0.0212
# Epoch [420/1000], Step [0/3], Loss: 0.0202
# Epoch [421/1000], Step [0/3], Loss: 0.0214
# Epoch [422/1000], Step [0/3], Loss: 0.0204
# Epoch [423/1000], Step [0/3], Loss: 0.0205
# Epoch [424/1000], Step [0/3], Loss: 0.0205
# Epoch [425/1000], Step [0/3], Loss: 0.0218
# Epoch [426/1000], Step [0/3], Loss: 0.0207
# Epoch [427/1000], Step [0/3], Loss: 0.0203
# Epoch [428/1000], Step [0/3], Loss: 0.0215
# Epoch [429/1000], Step [0/3], Loss: 0.0206
# Epoch [430/1000], Step [0/3], Loss: 0.0209
# Epoch [431/1000], Step [0/3], Loss: 0.0214
# Epoch [432/1000], Step [0/3], Loss: 0.0213
# Epoch [433/1000], Step [0/3], Loss: 0.0212
# Epoch [434/1000], Step [0/3], Loss: 0.0207
# Epoch [435/1000], Step [0/3], Loss: 0.0212
# Epoch [436/1000], Step [0/3], Loss: 0.0215
# Epoch [437/1000], Step [0/3], Loss: 0.0215
# Epoch [438/1000], Step [0/3], Loss: 0.0206
# Epoch [439/1000], Step [0/3], Loss: 0.0222
# Epoch [440/1000], Step [0/3], Loss: 0.0210
# Epoch [441/1000], Step [0/3], Loss: 0.0214
# Epoch [442/1000], Step [0/3], Loss: 0.0212
# Epoch [443/1000], Step [0/3], Loss: 0.0222
# Epoch [444/1000], Step [0/3], Loss: 0.0206
# Epoch [445/1000], Step [0/3], Loss: 0.0199
# Epoch [446/1000], Step [0/3], Loss: 0.0209
# Epoch [447/1000], Step [0/3], Loss: 0.0204
# Epoch [448/1000], Step [0/3], Loss: 0.0202
# Epoch [449/1000], Step [0/3], Loss: 0.0212
# Epoch [450/1000], Step [0/3], Loss: 0.0218
# Epoch [451/1000], Step [0/3], Loss: 0.0201
# Epoch [452/1000], Step [0/3], Loss: 0.0212
# Epoch [453/1000], Step [0/3], Loss: 0.0213
# Epoch [454/1000], Step [0/3], Loss: 0.0209
# Epoch [455/1000], Step [0/3], Loss: 0.0205
# Epoch [456/1000], Step [0/3], Loss: 0.0208
# Epoch [457/1000], Step [0/3], Loss: 0.0218
# Epoch [458/1000], Step [0/3], Loss: 0.0199
# Epoch [459/1000], Step [0/3], Loss: 0.0210
# Epoch [460/1000], Step [0/3], Loss: 0.0204
# Epoch [461/1000], Step [0/3], Loss: 0.0203
# Epoch [462/1000], Step [0/3], Loss: 0.0191
# Epoch [463/1000], Step [0/3], Loss: 0.0209
# Epoch [464/1000], Step [0/3], Loss: 0.0203
# Epoch [465/1000], Step [0/3], Loss: 0.0213
# Epoch [466/1000], Step [0/3], Loss: 0.0203
# Epoch [467/1000], Step [0/3], Loss: 0.0209
# Epoch [468/1000], Step [0/3], Loss: 0.0207
# Epoch [469/1000], Step [0/3], Loss: 0.0217
# Epoch [470/1000], Step [0/3], Loss: 0.0210
# Epoch [471/1000], Step [0/3], Loss: 0.0209
# Epoch [472/1000], Step [0/3], Loss: 0.0203
# Epoch [473/1000], Step [0/3], Loss: 0.0206
# Epoch [474/1000], Step [0/3], Loss: 0.0205
# Epoch [475/1000], Step [0/3], Loss: 0.0210
# Epoch [476/1000], Step [0/3], Loss: 0.0210
# Epoch [477/1000], Step [0/3], Loss: 0.0211
# Epoch [478/1000], Step [0/3], Loss: 0.0202
# Epoch [479/1000], Step [0/3], Loss: 0.0205
# Epoch [480/1000], Step [0/3], Loss: 0.0212
# Epoch [481/1000], Step [0/3], Loss: 0.0198
# Epoch [482/1000], Step [0/3], Loss: 0.0210
# Epoch [483/1000], Step [0/3], Loss: 0.0202
# Epoch [484/1000], Step [0/3], Loss: 0.0213
# Epoch [485/1000], Step [0/3], Loss: 0.0201
# Epoch [486/1000], Step [0/3], Loss: 0.0204
# Epoch [487/1000], Step [0/3], Loss: 0.0212
# Epoch [488/1000], Step [0/3], Loss: 0.0198
# Epoch [489/1000], Step [0/3], Loss: 0.0198
# Epoch [490/1000], Step [0/3], Loss: 0.0200
# Epoch [491/1000], Step [0/3], Loss: 0.0199
# Epoch [492/1000], Step [0/3], Loss: 0.0196
# Epoch [493/1000], Step [0/3], Loss: 0.0206
# Epoch [494/1000], Step [0/3], Loss: 0.0206
# Epoch [495/1000], Step [0/3], Loss: 0.0205
# Epoch [496/1000], Step [0/3], Loss: 0.0216
# Epoch [497/1000], Step [0/3], Loss: 0.0207
# Epoch [498/1000], Step [0/3], Loss: 0.0206
# Epoch [499/1000], Step [0/3], Loss: 0.0223
# Epoch [500/1000], Step [0/3], Loss: 0.0202
# Epoch [501/1000], Step [0/3], Loss: 0.0208
# Epoch [502/1000], Step [0/3], Loss: 0.0204
# Epoch [503/1000], Step [0/3], Loss: 0.0208
# Epoch [504/1000], Step [0/3], Loss: 0.0206
# Epoch [505/1000], Step [0/3], Loss: 0.0219
# Epoch [506/1000], Step [0/3], Loss: 0.0219
# Epoch [507/1000], Step [0/3], Loss: 0.0202
# Epoch [508/1000], Step [0/3], Loss: 0.0191
# Epoch [509/1000], Step [0/3], Loss: 0.0206
# Epoch [510/1000], Step [0/3], Loss: 0.0199
# Epoch [511/1000], Step [0/3], Loss: 0.0208
# Epoch [512/1000], Step [0/3], Loss: 0.0205
# Epoch [513/1000], Step [0/3], Loss: 0.0203
# Epoch [514/1000], Step [0/3], Loss: 0.0206
# Epoch [515/1000], Step [0/3], Loss: 0.0206
# Epoch [516/1000], Step [0/3], Loss: 0.0200
# Epoch [517/1000], Step [0/3], Loss: 0.0189
# Epoch [518/1000], Step [0/3], Loss: 0.0205
# Epoch [519/1000], Step [0/3], Loss: 0.0205
# Epoch [520/1000], Step [0/3], Loss: 0.0207
# Epoch [521/1000], Step [0/3], Loss: 0.0212
# Epoch [522/1000], Step [0/3], Loss: 0.0209
# Epoch [523/1000], Step [0/3], Loss: 0.0194
# Epoch [524/1000], Step [0/3], Loss: 0.0213
# Epoch [525/1000], Step [0/3], Loss: 0.0205
# Epoch [526/1000], Step [0/3], Loss: 0.0204
# Epoch [527/1000], Step [0/3], Loss: 0.0214
# Epoch [528/1000], Step [0/3], Loss: 0.0210
# Epoch [529/1000], Step [0/3], Loss: 0.0204
# Epoch [530/1000], Step [0/3], Loss: 0.0197
# Epoch [531/1000], Step [0/3], Loss: 0.0218
# Epoch [532/1000], Step [0/3], Loss: 0.0210
# Epoch [533/1000], Step [0/3], Loss: 0.0213
# Epoch [534/1000], Step [0/3], Loss: 0.0201
# Epoch [535/1000], Step [0/3], Loss: 0.0197
# Epoch [536/1000], Step [0/3], Loss: 0.0202
# Epoch [537/1000], Step [0/3], Loss: 0.0204
# Epoch [538/1000], Step [0/3], Loss: 0.0200
# Epoch [539/1000], Step [0/3], Loss: 0.0202
# Epoch [540/1000], Step [0/3], Loss: 0.0189
# Epoch [541/1000], Step [0/3], Loss: 0.0206
# Epoch [542/1000], Step [0/3], Loss: 0.0208
# Epoch [543/1000], Step [0/3], Loss: 0.0199
# Epoch [544/1000], Step [0/3], Loss: 0.0211
# Epoch [545/1000], Step [0/3], Loss: 0.0195
# Epoch [546/1000], Step [0/3], Loss: 0.0211
# Epoch [547/1000], Step [0/3], Loss: 0.0212
# Epoch [548/1000], Step [0/3], Loss: 0.0207
# Epoch [549/1000], Step [0/3], Loss: 0.0201
# Epoch [550/1000], Step [0/3], Loss: 0.0201
# Epoch [551/1000], Step [0/3], Loss: 0.0198
# Epoch [552/1000], Step [0/3], Loss: 0.0194
# Epoch [553/1000], Step [0/3], Loss: 0.0206
# Epoch [554/1000], Step [0/3], Loss: 0.0212
# Epoch [555/1000], Step [0/3], Loss: 0.0204
# Epoch [556/1000], Step [0/3], Loss: 0.0200
# Epoch [557/1000], Step [0/3], Loss: 0.0210
# Epoch [558/1000], Step [0/3], Loss: 0.0206
# Epoch [559/1000], Step [0/3], Loss: 0.0201
# Epoch [560/1000], Step [0/3], Loss: 0.0208
# Epoch [561/1000], Step [0/3], Loss: 0.0199
# Epoch [562/1000], Step [0/3], Loss: 0.0215
# Epoch [563/1000], Step [0/3], Loss: 0.0212
# Epoch [564/1000], Step [0/3], Loss: 0.0199
# Epoch [565/1000], Step [0/3], Loss: 0.0213
# Epoch [566/1000], Step [0/3], Loss: 0.0202
# Epoch [567/1000], Step [0/3], Loss: 0.0202
# Epoch [568/1000], Step [0/3], Loss: 0.0209
# Epoch [569/1000], Step [0/3], Loss: 0.0199
# Epoch [570/1000], Step [0/3], Loss: 0.0190
# Epoch [571/1000], Step [0/3], Loss: 0.0210
# Epoch [572/1000], Step [0/3], Loss: 0.0211
# Epoch [573/1000], Step [0/3], Loss: 0.0202
# Epoch [574/1000], Step [0/3], Loss: 0.0198
# Epoch [575/1000], Step [0/3], Loss: 0.0191
# Epoch [576/1000], Step [0/3], Loss: 0.0222
# Epoch [577/1000], Step [0/3], Loss: 0.0204
# Epoch [578/1000], Step [0/3], Loss: 0.0206
# Epoch [579/1000], Step [0/3], Loss: 0.0209
# Epoch [580/1000], Step [0/3], Loss: 0.0208
# Epoch [581/1000], Step [0/3], Loss: 0.0199
# Epoch [582/1000], Step [0/3], Loss: 0.0207
# Epoch [583/1000], Step [0/3], Loss: 0.0199
# Epoch [584/1000], Step [0/3], Loss: 0.0200
# Epoch [585/1000], Step [0/3], Loss: 0.0213
# Epoch [586/1000], Step [0/3], Loss: 0.0206
# Epoch [587/1000], Step [0/3], Loss: 0.0209
# Epoch [588/1000], Step [0/3], Loss: 0.0203
# Epoch [589/1000], Step [0/3], Loss: 0.0207
# Epoch [590/1000], Step [0/3], Loss: 0.0201
# Epoch [591/1000], Step [0/3], Loss: 0.0206
# Epoch [592/1000], Step [0/3], Loss: 0.0194
# Epoch [593/1000], Step [0/3], Loss: 0.0201
# Epoch [594/1000], Step [0/3], Loss: 0.0203
# Epoch [595/1000], Step [0/3], Loss: 0.0204
# Epoch [596/1000], Step [0/3], Loss: 0.0202
# Epoch [597/1000], Step [0/3], Loss: 0.0205
# Epoch [598/1000], Step [0/3], Loss: 0.0201
# Epoch [599/1000], Step [0/3], Loss: 0.0203
# Epoch [600/1000], Step [0/3], Loss: 0.0204
# Epoch [601/1000], Step [0/3], Loss: 0.0199
# Epoch [602/1000], Step [0/3], Loss: 0.0196
# Epoch [603/1000], Step [0/3], Loss: 0.0203
# Epoch [604/1000], Step [0/3], Loss: 0.0205
# Epoch [605/1000], Step [0/3], Loss: 0.0220
# Epoch [606/1000], Step [0/3], Loss: 0.0204
# Epoch [607/1000], Step [0/3], Loss: 0.0190
# Epoch [608/1000], Step [0/3], Loss: 0.0212
# Epoch [609/1000], Step [0/3], Loss: 0.0203
# Epoch [610/1000], Step [0/3], Loss: 0.0201
# Epoch [611/1000], Step [0/3], Loss: 0.0203
# Epoch [612/1000], Step [0/3], Loss: 0.0200
# Epoch [613/1000], Step [0/3], Loss: 0.0210
# Epoch [614/1000], Step [0/3], Loss: 0.0203
# Epoch [615/1000], Step [0/3], Loss: 0.0201
# Epoch [616/1000], Step [0/3], Loss: 0.0203
# Epoch [617/1000], Step [0/3], Loss: 0.0194
# Epoch [618/1000], Step [0/3], Loss: 0.0207
# Epoch [619/1000], Step [0/3], Loss: 0.0198
# Epoch [620/1000], Step [0/3], Loss: 0.0198
# Epoch [621/1000], Step [0/3], Loss: 0.0189
# Epoch [622/1000], Step [0/3], Loss: 0.0197
# Epoch [623/1000], Step [0/3], Loss: 0.0204
# Epoch [624/1000], Step [0/3], Loss: 0.0204
# Epoch [625/1000], Step [0/3], Loss: 0.0214
# Epoch [626/1000], Step [0/3], Loss: 0.0202
# Epoch [627/1000], Step [0/3], Loss: 0.0196
# Epoch [628/1000], Step [0/3], Loss: 0.0201
# Epoch [629/1000], Step [0/3], Loss: 0.0198
# Epoch [630/1000], Step [0/3], Loss: 0.0194
# Epoch [631/1000], Step [0/3], Loss: 0.0205
# Epoch [632/1000], Step [0/3], Loss: 0.0205
# Epoch [633/1000], Step [0/3], Loss: 0.0207
# Epoch [634/1000], Step [0/3], Loss: 0.0210
# Epoch [635/1000], Step [0/3], Loss: 0.0187
# Epoch [636/1000], Step [0/3], Loss: 0.0201
# Epoch [637/1000], Step [0/3], Loss: 0.0198
# Epoch [638/1000], Step [0/3], Loss: 0.0198
# Epoch [639/1000], Step [0/3], Loss: 0.0187
# Epoch [640/1000], Step [0/3], Loss: 0.0197
# Epoch [641/1000], Step [0/3], Loss: 0.0208
# Epoch [642/1000], Step [0/3], Loss: 0.0201
# Epoch [643/1000], Step [0/3], Loss: 0.0202
# Epoch [644/1000], Step [0/3], Loss: 0.0195
# Epoch [645/1000], Step [0/3], Loss: 0.0205
# Epoch [646/1000], Step [0/3], Loss: 0.0209
# Epoch [647/1000], Step [0/3], Loss: 0.0198
# Epoch [648/1000], Step [0/3], Loss: 0.0196
# Epoch [649/1000], Step [0/3], Loss: 0.0204
# Epoch [650/1000], Step [0/3], Loss: 0.0201
# Epoch [651/1000], Step [0/3], Loss: 0.0203
# Epoch [652/1000], Step [0/3], Loss: 0.0200
# Epoch [653/1000], Step [0/3], Loss: 0.0192
# Epoch [654/1000], Step [0/3], Loss: 0.0195
# Epoch [655/1000], Step [0/3], Loss: 0.0213
# Epoch [656/1000], Step [0/3], Loss: 0.0201
# Epoch [657/1000], Step [0/3], Loss: 0.0200
# Epoch [658/1000], Step [0/3], Loss: 0.0210
# Epoch [659/1000], Step [0/3], Loss: 0.0205
# Epoch [660/1000], Step [0/3], Loss: 0.0205
# Epoch [661/1000], Step [0/3], Loss: 0.0201
# Epoch [662/1000], Step [0/3], Loss: 0.0192
# Epoch [663/1000], Step [0/3], Loss: 0.0215
# Epoch [664/1000], Step [0/3], Loss: 0.0207
# Epoch [665/1000], Step [0/3], Loss: 0.0213
# Epoch [666/1000], Step [0/3], Loss: 0.0212
# Epoch [667/1000], Step [0/3], Loss: 0.0207
# Epoch [668/1000], Step [0/3], Loss: 0.0202
# Epoch [669/1000], Step [0/3], Loss: 0.0200
# Epoch [670/1000], Step [0/3], Loss: 0.0203
# Epoch [671/1000], Step [0/3], Loss: 0.0204
# Epoch [672/1000], Step [0/3], Loss: 0.0208
# Epoch [673/1000], Step [0/3], Loss: 0.0199
# Epoch [674/1000], Step [0/3], Loss: 0.0201
# Epoch [675/1000], Step [0/3], Loss: 0.0208
# Epoch [676/1000], Step [0/3], Loss: 0.0204
# Epoch [677/1000], Step [0/3], Loss: 0.0210
# Epoch [678/1000], Step [0/3], Loss: 0.0202
# Epoch [679/1000], Step [0/3], Loss: 0.0196
# Epoch [680/1000], Step [0/3], Loss: 0.0205
# Epoch [681/1000], Step [0/3], Loss: 0.0202
# Epoch [682/1000], Step [0/3], Loss: 0.0208
# Epoch [683/1000], Step [0/3], Loss: 0.0199
# Epoch [684/1000], Step [0/3], Loss: 0.0202
# Epoch [685/1000], Step [0/3], Loss: 0.0207
# Epoch [686/1000], Step [0/3], Loss: 0.0207
# Epoch [687/1000], Step [0/3], Loss: 0.0191
# Epoch [688/1000], Step [0/3], Loss: 0.0200
# Epoch [689/1000], Step [0/3], Loss: 0.0209
# Epoch [690/1000], Step [0/3], Loss: 0.0188
# Epoch [691/1000], Step [0/3], Loss: 0.0210
# Epoch [692/1000], Step [0/3], Loss: 0.0204
# Epoch [693/1000], Step [0/3], Loss: 0.0200
# Epoch [694/1000], Step [0/3], Loss: 0.0195
# Epoch [695/1000], Step [0/3], Loss: 0.0199
# Epoch [696/1000], Step [0/3], Loss: 0.0193
# Epoch [697/1000], Step [0/3], Loss: 0.0188
# Epoch [698/1000], Step [0/3], Loss: 0.0189
# Epoch [699/1000], Step [0/3], Loss: 0.0199
# Epoch [700/1000], Step [0/3], Loss: 0.0200
# Epoch [701/1000], Step [0/3], Loss: 0.0209
# Epoch [702/1000], Step [0/3], Loss: 0.0202
# Epoch [703/1000], Step [0/3], Loss: 0.0205
# Epoch [704/1000], Step [0/3], Loss: 0.0207
# Epoch [705/1000], Step [0/3], Loss: 0.0204
# Epoch [706/1000], Step [0/3], Loss: 0.0197
# Epoch [707/1000], Step [0/3], Loss: 0.0189
# Epoch [708/1000], Step [0/3], Loss: 0.0206
# Epoch [709/1000], Step [0/3], Loss: 0.0204
# Epoch [710/1000], Step [0/3], Loss: 0.0198
# Epoch [711/1000], Step [0/3], Loss: 0.0201
# Epoch [712/1000], Step [0/3], Loss: 0.0204
# Epoch [713/1000], Step [0/3], Loss: 0.0197
# Epoch [714/1000], Step [0/3], Loss: 0.0195
# Epoch [715/1000], Step [0/3], Loss: 0.0198
# Epoch [716/1000], Step [0/3], Loss: 0.0198
# Epoch [717/1000], Step [0/3], Loss: 0.0209
# Epoch [718/1000], Step [0/3], Loss: 0.0200
# Epoch [719/1000], Step [0/3], Loss: 0.0195
# Epoch [720/1000], Step [0/3], Loss: 0.0199
# Epoch [721/1000], Step [0/3], Loss: 0.0196
# Epoch [722/1000], Step [0/3], Loss: 0.0209
# Epoch [723/1000], Step [0/3], Loss: 0.0185
# Epoch [724/1000], Step [0/3], Loss: 0.0204
# Epoch [725/1000], Step [0/3], Loss: 0.0192
# Epoch [726/1000], Step [0/3], Loss: 0.0193
# Epoch [727/1000], Step [0/3], Loss: 0.0201
# Epoch [728/1000], Step [0/3], Loss: 0.0199
# Epoch [729/1000], Step [0/3], Loss: 0.0185
# Epoch [730/1000], Step [0/3], Loss: 0.0197
# Epoch [731/1000], Step [0/3], Loss: 0.0211
# Epoch [732/1000], Step [0/3], Loss: 0.0199
# Epoch [733/1000], Step [0/3], Loss: 0.0209
# Epoch [734/1000], Step [0/3], Loss: 0.0203
# Epoch [735/1000], Step [0/3], Loss: 0.0203
# Epoch [736/1000], Step [0/3], Loss: 0.0190
# Epoch [737/1000], Step [0/3], Loss: 0.0203
# Epoch [738/1000], Step [0/3], Loss: 0.0205
# Epoch [739/1000], Step [0/3], Loss: 0.0206
# Epoch [740/1000], Step [0/3], Loss: 0.0195
# Epoch [741/1000], Step [0/3], Loss: 0.0202
# Epoch [742/1000], Step [0/3], Loss: 0.0198
# Epoch [743/1000], Step [0/3], Loss: 0.0198
# Epoch [744/1000], Step [0/3], Loss: 0.0211
# Epoch [745/1000], Step [0/3], Loss: 0.0201
# Epoch [746/1000], Step [0/3], Loss: 0.0190
# Epoch [747/1000], Step [0/3], Loss: 0.0195
# Epoch [748/1000], Step [0/3], Loss: 0.0194
# Epoch [749/1000], Step [0/3], Loss: 0.0194
# Epoch [750/1000], Step [0/3], Loss: 0.0209
# Epoch [751/1000], Step [0/3], Loss: 0.0199
# Epoch [752/1000], Step [0/3], Loss: 0.0193
# Epoch [753/1000], Step [0/3], Loss: 0.0207
# Epoch [754/1000], Step [0/3], Loss: 0.0200
# Epoch [755/1000], Step [0/3], Loss: 0.0204
# Epoch [756/1000], Step [0/3], Loss: 0.0195
# Epoch [757/1000], Step [0/3], Loss: 0.0199
# Epoch [758/1000], Step [0/3], Loss: 0.0196
# Epoch [759/1000], Step [0/3], Loss: 0.0191
# Epoch [760/1000], Step [0/3], Loss: 0.0206
# Epoch [761/1000], Step [0/3], Loss: 0.0195
# Epoch [762/1000], Step [0/3], Loss: 0.0196
# Epoch [763/1000], Step [0/3], Loss: 0.0200
# Epoch [764/1000], Step [0/3], Loss: 0.0201
# Epoch [765/1000], Step [0/3], Loss: 0.0198
# Epoch [766/1000], Step [0/3], Loss: 0.0207
# Epoch [767/1000], Step [0/3], Loss: 0.0199
# Epoch [768/1000], Step [0/3], Loss: 0.0201
# Epoch [769/1000], Step [0/3], Loss: 0.0206
# Epoch [770/1000], Step [0/3], Loss: 0.0201
# Epoch [771/1000], Step [0/3], Loss: 0.0205
# Epoch [772/1000], Step [0/3], Loss: 0.0200
# Epoch [773/1000], Step [0/3], Loss: 0.0193
# Epoch [774/1000], Step [0/3], Loss: 0.0193
# Epoch [775/1000], Step [0/3], Loss: 0.0190
# Epoch [776/1000], Step [0/3], Loss: 0.0194
# Epoch [777/1000], Step [0/3], Loss: 0.0193
# Epoch [778/1000], Step [0/3], Loss: 0.0194
# Epoch [779/1000], Step [0/3], Loss: 0.0203
# Epoch [780/1000], Step [0/3], Loss: 0.0203
# Epoch [781/1000], Step [0/3], Loss: 0.0196
# Epoch [782/1000], Step [0/3], Loss: 0.0197
# Epoch [783/1000], Step [0/3], Loss: 0.0193
# Epoch [784/1000], Step [0/3], Loss: 0.0202
# Epoch [785/1000], Step [0/3], Loss: 0.0199
# Epoch [786/1000], Step [0/3], Loss: 0.0185
# Epoch [787/1000], Step [0/3], Loss: 0.0192
# Epoch [788/1000], Step [0/3], Loss: 0.0205
# Epoch [789/1000], Step [0/3], Loss: 0.0206
# Epoch [790/1000], Step [0/3], Loss: 0.0190
# Epoch [791/1000], Step [0/3], Loss: 0.0209
# Epoch [792/1000], Step [0/3], Loss: 0.0201
# Epoch [793/1000], Step [0/3], Loss: 0.0187
# Epoch [794/1000], Step [0/3], Loss: 0.0193
# Epoch [795/1000], Step [0/3], Loss: 0.0197
# Epoch [796/1000], Step [0/3], Loss: 0.0201
# Epoch [797/1000], Step [0/3], Loss: 0.0203
# Epoch [798/1000], Step [0/3], Loss: 0.0202
# Epoch [799/1000], Step [0/3], Loss: 0.0191
# Epoch [800/1000], Step [0/3], Loss: 0.0209
# Epoch [801/1000], Step [0/3], Loss: 0.0191
# Epoch [802/1000], Step [0/3], Loss: 0.0202
# Epoch [803/1000], Step [0/3], Loss: 0.0209
# Epoch [804/1000], Step [0/3], Loss: 0.0206
# Epoch [805/1000], Step [0/3], Loss: 0.0202
# Epoch [806/1000], Step [0/3], Loss: 0.0201
# Epoch [807/1000], Step [0/3], Loss: 0.0193
# Epoch [808/1000], Step [0/3], Loss: 0.0208
# Epoch [809/1000], Step [0/3], Loss: 0.0193
# Epoch [810/1000], Step [0/3], Loss: 0.0202
# Epoch [811/1000], Step [0/3], Loss: 0.0209
# Epoch [812/1000], Step [0/3], Loss: 0.0194
# Epoch [813/1000], Step [0/3], Loss: 0.0195
# Epoch [814/1000], Step [0/3], Loss: 0.0205
# Epoch [815/1000], Step [0/3], Loss: 0.0197
# Epoch [816/1000], Step [0/3], Loss: 0.0210
# Epoch [817/1000], Step [0/3], Loss: 0.0196
# Epoch [818/1000], Step [0/3], Loss: 0.0201
# Epoch [819/1000], Step [0/3], Loss: 0.0200
# Epoch [820/1000], Step [0/3], Loss: 0.0206
# Epoch [821/1000], Step [0/3], Loss: 0.0197
# Epoch [822/1000], Step [0/3], Loss: 0.0204
# Epoch [823/1000], Step [0/3], Loss: 0.0203
# Epoch [824/1000], Step [0/3], Loss: 0.0195
# Epoch [825/1000], Step [0/3], Loss: 0.0214
# Epoch [826/1000], Step [0/3], Loss: 0.0194
# Epoch [827/1000], Step [0/3], Loss: 0.0205
# Epoch [828/1000], Step [0/3], Loss: 0.0197
# Epoch [829/1000], Step [0/3], Loss: 0.0205
# Epoch [830/1000], Step [0/3], Loss: 0.0198
# Epoch [831/1000], Step [0/3], Loss: 0.0208
# Epoch [832/1000], Step [0/3], Loss: 0.0206
# Epoch [833/1000], Step [0/3], Loss: 0.0197
# Epoch [834/1000], Step [0/3], Loss: 0.0197
# Epoch [835/1000], Step [0/3], Loss: 0.0189
# Epoch [836/1000], Step [0/3], Loss: 0.0198
# Epoch [837/1000], Step [0/3], Loss: 0.0197
# Epoch [838/1000], Step [0/3], Loss: 0.0202
# Epoch [839/1000], Step [0/3], Loss: 0.0201
# Epoch [840/1000], Step [0/3], Loss: 0.0207
# Epoch [841/1000], Step [0/3], Loss: 0.0198
# Epoch [842/1000], Step [0/3], Loss: 0.0199
# Epoch [843/1000], Step [0/3], Loss: 0.0201
# Epoch [844/1000], Step [0/3], Loss: 0.0196
# Epoch [845/1000], Step [0/3], Loss: 0.0192
# Epoch [846/1000], Step [0/3], Loss: 0.0202
# Epoch [847/1000], Step [0/3], Loss: 0.0191
# Epoch [848/1000], Step [0/3], Loss: 0.0194
# Epoch [849/1000], Step [0/3], Loss: 0.0194
# Epoch [850/1000], Step [0/3], Loss: 0.0182
# Epoch [851/1000], Step [0/3], Loss: 0.0204
# Epoch [852/1000], Step [0/3], Loss: 0.0196
# Epoch [853/1000], Step [0/3], Loss: 0.0198
# Epoch [854/1000], Step [0/3], Loss: 0.0181
# Epoch [855/1000], Step [0/3], Loss: 0.0202
# Epoch [856/1000], Step [0/3], Loss: 0.0194
# Epoch [857/1000], Step [0/3], Loss: 0.0191
# Epoch [858/1000], Step [0/3], Loss: 0.0201
# Epoch [859/1000], Step [0/3], Loss: 0.0199
# Epoch [860/1000], Step [0/3], Loss: 0.0199
# Epoch [861/1000], Step [0/3], Loss: 0.0192
# Epoch [862/1000], Step [0/3], Loss: 0.0203
# Epoch [863/1000], Step [0/3], Loss: 0.0200
# Epoch [864/1000], Step [0/3], Loss: 0.0204
# Epoch [865/1000], Step [0/3], Loss: 0.0204
# Epoch [866/1000], Step [0/3], Loss: 0.0199
# Epoch [867/1000], Step [0/3], Loss: 0.0208
# Epoch [868/1000], Step [0/3], Loss: 0.0197
# Epoch [869/1000], Step [0/3], Loss: 0.0202
# Epoch [870/1000], Step [0/3], Loss: 0.0186
# Epoch [871/1000], Step [0/3], Loss: 0.0194
# Epoch [872/1000], Step [0/3], Loss: 0.0196
# Epoch [873/1000], Step [0/3], Loss: 0.0192
# Epoch [874/1000], Step [0/3], Loss: 0.0193
# Epoch [875/1000], Step [0/3], Loss: 0.0208
# Epoch [876/1000], Step [0/3], Loss: 0.0185
# Epoch [877/1000], Step [0/3], Loss: 0.0193
# Epoch [878/1000], Step [0/3], Loss: 0.0202
# Epoch [879/1000], Step [0/3], Loss: 0.0195
# Epoch [880/1000], Step [0/3], Loss: 0.0204
# Epoch [881/1000], Step [0/3], Loss: 0.0182
# Epoch [882/1000], Step [0/3], Loss: 0.0200
# Epoch [883/1000], Step [0/3], Loss: 0.0186
# Epoch [884/1000], Step [0/3], Loss: 0.0207
# Epoch [885/1000], Step [0/3], Loss: 0.0206
# Epoch [886/1000], Step [0/3], Loss: 0.0201
# Epoch [887/1000], Step [0/3], Loss: 0.0209
# Epoch [888/1000], Step [0/3], Loss: 0.0201
# Epoch [889/1000], Step [0/3], Loss: 0.0202
# Epoch [890/1000], Step [0/3], Loss: 0.0201
# Epoch [891/1000], Step [0/3], Loss: 0.0204
# Epoch [892/1000], Step [0/3], Loss: 0.0198
# Epoch [893/1000], Step [0/3], Loss: 0.0199
# Epoch [894/1000], Step [0/3], Loss: 0.0199
# Epoch [895/1000], Step [0/3], Loss: 0.0193
# Epoch [896/1000], Step [0/3], Loss: 0.0194
# Epoch [897/1000], Step [0/3], Loss: 0.0194
# Epoch [898/1000], Step [0/3], Loss: 0.0196
# Epoch [899/1000], Step [0/3], Loss: 0.0209
# Epoch [900/1000], Step [0/3], Loss: 0.0204
# Epoch [901/1000], Step [0/3], Loss: 0.0200
# Epoch [902/1000], Step [0/3], Loss: 0.0203
# Epoch [903/1000], Step [0/3], Loss: 0.0201
# Epoch [904/1000], Step [0/3], Loss: 0.0199
# Epoch [905/1000], Step [0/3], Loss: 0.0194
# Epoch [906/1000], Step [0/3], Loss: 0.0197
# Epoch [907/1000], Step [0/3], Loss: 0.0197
# Epoch [908/1000], Step [0/3], Loss: 0.0192
# Epoch [909/1000], Step [0/3], Loss: 0.0197
# Epoch [910/1000], Step [0/3], Loss: 0.0194
# Epoch [911/1000], Step [0/3], Loss: 0.0200
# Epoch [912/1000], Step [0/3], Loss: 0.0198
# Epoch [913/1000], Step [0/3], Loss: 0.0199
# Epoch [914/1000], Step [0/3], Loss: 0.0191
# Epoch [915/1000], Step [0/3], Loss: 0.0208
# Epoch [916/1000], Step [0/3], Loss: 0.0194
# Epoch [917/1000], Step [0/3], Loss: 0.0200
# Epoch [918/1000], Step [0/3], Loss: 0.0198
# Epoch [919/1000], Step [0/3], Loss: 0.0199
# Epoch [920/1000], Step [0/3], Loss: 0.0204
# Epoch [921/1000], Step [0/3], Loss: 0.0195
# Epoch [922/1000], Step [0/3], Loss: 0.0186
# Epoch [923/1000], Step [0/3], Loss: 0.0193
# Epoch [924/1000], Step [0/3], Loss: 0.0203
# Epoch [925/1000], Step [0/3], Loss: 0.0199
# Epoch [926/1000], Step [0/3], Loss: 0.0194
# Epoch [927/1000], Step [0/3], Loss: 0.0196
# Epoch [928/1000], Step [0/3], Loss: 0.0187
# Epoch [929/1000], Step [0/3], Loss: 0.0195
# Epoch [930/1000], Step [0/3], Loss: 0.0199
# Epoch [931/1000], Step [0/3], Loss: 0.0198
# Epoch [932/1000], Step [0/3], Loss: 0.0201
# Epoch [933/1000], Step [0/3], Loss: 0.0208
# Epoch [934/1000], Step [0/3], Loss: 0.0196
# Epoch [935/1000], Step [0/3], Loss: 0.0189
# Epoch [936/1000], Step [0/3], Loss: 0.0194
# Epoch [937/1000], Step [0/3], Loss: 0.0197
# Epoch [938/1000], Step [0/3], Loss: 0.0202
# Epoch [939/1000], Step [0/3], Loss: 0.0207
# Epoch [940/1000], Step [0/3], Loss: 0.0195
# Epoch [941/1000], Step [0/3], Loss: 0.0200
# Epoch [942/1000], Step [0/3], Loss: 0.0203
# Epoch [943/1000], Step [0/3], Loss: 0.0200
# Epoch [944/1000], Step [0/3], Loss: 0.0196
# Epoch [945/1000], Step [0/3], Loss: 0.0194
# Epoch [946/1000], Step [0/3], Loss: 0.0187
# Epoch [947/1000], Step [0/3], Loss: 0.0197
# Epoch [948/1000], Step [0/3], Loss: 0.0198
# Epoch [949/1000], Step [0/3], Loss: 0.0196
# Epoch [950/1000], Step [0/3], Loss: 0.0197
# Epoch [951/1000], Step [0/3], Loss: 0.0192
# Epoch [952/1000], Step [0/3], Loss: 0.0191
# Epoch [953/1000], Step [0/3], Loss: 0.0209
# Epoch [954/1000], Step [0/3], Loss: 0.0195
# Epoch [955/1000], Step [0/3], Loss: 0.0200
# Epoch [956/1000], Step [0/3], Loss: 0.0209
# Epoch [957/1000], Step [0/3], Loss: 0.0193
# Epoch [958/1000], Step [0/3], Loss: 0.0201
# Epoch [959/1000], Step [0/3], Loss: 0.0198
# Epoch [960/1000], Step [0/3], Loss: 0.0186
# Epoch [961/1000], Step [0/3], Loss: 0.0192
# Epoch [962/1000], Step [0/3], Loss: 0.0188
# Epoch [963/1000], Step [0/3], Loss: 0.0196
# Epoch [964/1000], Step [0/3], Loss: 0.0195
# Epoch [965/1000], Step [0/3], Loss: 0.0201
# Epoch [966/1000], Step [0/3], Loss: 0.0210
# Epoch [967/1000], Step [0/3], Loss: 0.0191
# Epoch [968/1000], Step [0/3], Loss: 0.0196
# Epoch [969/1000], Step [0/3], Loss: 0.0208
# Epoch [970/1000], Step [0/3], Loss: 0.0203
# Epoch [971/1000], Step [0/3], Loss: 0.0197
# Epoch [972/1000], Step [0/3], Loss: 0.0201
# Epoch [973/1000], Step [0/3], Loss: 0.0194
# Epoch [974/1000], Step [0/3], Loss: 0.0192
# Epoch [975/1000], Step [0/3], Loss: 0.0186
# Epoch [976/1000], Step [0/3], Loss: 0.0201
# Epoch [977/1000], Step [0/3], Loss: 0.0197
# Epoch [978/1000], Step [0/3], Loss: 0.0204
# Epoch [979/1000], Step [0/3], Loss: 0.0197
# Epoch [980/1000], Step [0/3], Loss: 0.0185
# Epoch [981/1000], Step [0/3], Loss: 0.0200
# Epoch [982/1000], Step [0/3], Loss: 0.0192
# Epoch [983/1000], Step [0/3], Loss: 0.0186
# Epoch [984/1000], Step [0/3], Loss: 0.0198
# Epoch [985/1000], Step [0/3], Loss: 0.0207
# Epoch [986/1000], Step [0/3], Loss: 0.0196
# Epoch [987/1000], Step [0/3], Loss: 0.0204
# Epoch [988/1000], Step [0/3], Loss: 0.0193
# Epoch [989/1000], Step [0/3], Loss: 0.0199
# Epoch [990/1000], Step [0/3], Loss: 0.0204
# Epoch [991/1000], Step [0/3], Loss: 0.0195
# Epoch [992/1000], Step [0/3], Loss: 0.0188
# Epoch [993/1000], Step [0/3], Loss: 0.0201
# Epoch [994/1000], Step [0/3], Loss: 0.0203
# Epoch [995/1000], Step [0/3], Loss: 0.0195
# Epoch [996/1000], Step [0/3], Loss: 0.0202
# Epoch [997/1000], Step [0/3], Loss: 0.0204
# Epoch [998/1000], Step [0/3], Loss: 0.0184
# Epoch [999/1000], Step [0/3], Loss: 0.0204

# %%
# Generate new spritesheet
sprite_width, sprite_height = dataset.get_sprite_dimensions()
# get the first pose of first mascot from main.png
new_mascot_pose = dataset.sprites[0, 0]

# Resize input pose to match original dimensions
new_mascot_pose = cv2.resize(new_mascot_pose, (sprite_width, sprite_height))

spritesheet = generate_spritesheet(
	model,
	new_mascot_pose,
	num_poses=26,
	original_width=sprite_width,
	original_height=sprite_height
)

cv2.imwrite('new_mascot_spritesheet.png', spritesheet)
# Out:
# True
